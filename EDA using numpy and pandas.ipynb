# %% [markdown]
# ### Exploratory Data Analysis (EDA) using NumPy and Pandas

# %% [markdown]
# What is EDA?
#
# -> Exploratory Data Analysis (EDA) is the process of understanding, cleaning, analyzing, and visualizing data before applying machine learning or statistical techniques.

# %% [markdown]
# EDA using

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Titanic dataset.csv.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 10)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare
# 881    male  33.0      0      0            349257   7.8958
# ...

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 43            44         1       2
# 806          807         0       1
# 413          414         0       2
# 411          412         0       3
# 272          273         1       2
# 742          743         1       1
# 1              2         1       1
# 293          294         0       3
# 843          844         0       3
# 270          271         0       1
# 869          870         1       3
# 550          551         1       1
# 72            73         0       2
# 201          202         0       3
# 127          128         1       3
# 657          658         0       3
# 457          458         1       1
# 211          212         1       2
# 241          242         1       3
# 605          606         0       3
# 557          558         0       1
# 775          776         0       3
# 239          240         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ### Checking missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# dtype: int64

# %%
missing_percent =(df.isnull().sum()/len(df))*100
missing_percent.sort_values(ascending=False)
# Out:
# Age            19.86532
# PassengerId     0.00000
# Survived        0.00000
# Pclass          0.00000
# Name            0.00000
# Sex             0.00000
# SibSp           0.00000
# Parch           0.00000
# Ticket          0.00000
# Fare            0.00000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# dtype: object

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[["Age","Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
Q1 = df["Fare"].quantile(0.25)
Q3 = df["Fare"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[
    (df["Fare"] < lower) |
    (df["Fare"] > upper)
]

len(outliers)
# Out:
# 116

# %% [markdown]
# ### NumPy Statistical Analysis

# %%
numeric_cols = ["Age", "Fare"]

# %%
np.mean(df["Age"])
np.mean(df["Fare"])
# Out:
# np.float64(32.204207968574636)

# %%
np.median(df["Age"].dropna())
# Out:
# np.float64(28.0)

# %%
np.median(df["Fare"])
# Out:
# np.float64(14.4542)

# %%
np.var(df["Age"].dropna())
np.var(df["Fare"])
# Out:
# 2466.6653116850434

# %%
np.std(df["Age"].dropna())
np.std(df["Fare"])
# Out:
# 49.66553444477411

# %%
np.percentile(df["Age"].dropna(), [25,50,75])
# Out:
# array([20.125, 28.   , 38.   ])

# %%
np.percentile(df["Fare"], [25,50,75])
# Out:
# array([ 7.9104, 14.4542, 31.    ])

# %%
np.min(df["Age"])
np.max(df["Age"])

np.min(df["Fare"])
np.max(df["Fare"])
# Out:
# 512.3292

# %% [markdown]
# ### Univariate Analysis

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

print(numeric_cols)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
col = "Age"

print("Mean:", np.mean(df[col]))
print("Median:", np.median(df[col].dropna()))
print("Std:", np.std(df[col].dropna()))
print("Min:", np.min(df[col]))
print("Max:", np.max(df[col]))
print("Missing:", df[col].isnull().sum())
# Out:
# Mean: 29.69911764705882
# Median: 28.0
# Std: 14.516321150817317
# Min: 0.42
# Max: 80.0
# Missing: 177

# %%
col = "Fare"

print("Mean:", np.mean(df[col]))
print("Median:", np.median(df[col]))
print("Std:", np.std(df[col]))
print("Min:", np.min(df[col]))
print("Max:", np.max(df[col]))
# Out:
# Mean: 32.204207968574636
# Median: 14.4542
# Std: 49.66553444477411
# Min: 0.0
# Max: 512.3292

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
(df["Sex"].value_counts(normalize=True)*100).round(2)
# Out:
# Sex
# male      64.76
# female    35.24
# Name: proportion, dtype: float64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
(df["Pclass"].value_counts(normalize=True)*100).round(2)
# Out:
# Pclass
# 3    55.11
# 1    24.24
# 2    20.65
# Name: proportion, dtype: float64

# %%
pd.crosstab(df["Sex"], df["Survived"])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(
    df["Sex"],
    df["Survived"],
    normalize="index"
) * 100
# Out:
# Survived          0          1
# Sex
# female    25.796178  74.203822
# male      81.109185  18.890815

# %%
pd.crosstab(
    df["Pclass"],
    df["Survived"],
    normalize="index"
) * 100
# Out:
# Survived          0          1
# Pclass
# 1         37.037037  62.962963
# 2         52.717391  47.282609
# 3         75.763747  24.236253

# %% [markdown]
# ### Correlation Analysis

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)["Survived"]
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.groupby("Survived")["Age"].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
df.groupby("Survived")["Fare"].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %% [markdown]
# ### The survivor had pay more higher fees than non survivor or we can say they are from wealthy family

# %%
corr = df.corr(numeric_only=True)
corr["Survived"].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64
